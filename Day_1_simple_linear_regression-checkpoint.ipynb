# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('data_house.csv')

# %%
dataset.head()
# Out:
#    Unnamed: 0          id             date   price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900         3       1.00
# 1           1  6414100192  20141209T000000  538000         3       2.25
# 2           2  5631500400  20150225T000000  180000         2       1.00
# 3           3  2487200875  20141209T000000  604000         4       3.00
# 4           4  1954400510  20150218T000000  510000         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  view  condition
# 0         1180      5650     1.0           0     0          3
# 1         2570      7242     2.0           0     0          3
# 2          770     10000     1.0           0     0          3
# 3         1960      5000     1.0           0     0          5
# 4         1680      8080     1.0           0     0          3

# %%
dataset.isna().sum()
# Out:
# Unnamed: 0     0
# id             0
# date           0
# price          0
# bedrooms       0
# bathrooms      0
# sqft_living    0
# sqft_lot       0
# floors         0
# waterfront     0
# view           0
# condition      0
# dtype: int64

# %%
d=dataset.iloc[:,3:5]
d.head()
# Out:
#     price  bedrooms
# 0  221900         3
# 1  538000         3
# 2  180000         2
# 3  604000         4
# 4  510000         3

# %%
d.isna().sum()
# Out:
# price       0
# bedrooms    0
# dtype: int64

# %%
X=d.iloc[:,1:].values
y=d.iloc[:,:-1].values

# %%
X
# Out:
# array([[3],
#        [3],
#        [2],
#        [4],
#        [3],
#        [4],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [2],
#        [3],
#        [3],
#        [5],
#        [4],
#        [3],
#        [4],
#        [2],
#        [3],
#        [4],
#        [3],
#        [5],
#        [2],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [4],
#        [3],
#        [2],
#        [4],
#        [3],
#        [4],
#        [3],
#        [4],
#        [4],
#        [4],
#        [4],
#        [4],
#        [4],
#        [5],
#        [3],
#        [3],
#        [3],
#        [3],
#        [4],
#        [3],
#        [3],
#        [3],
#        [5],
#        [3],
#        [2],
#        [5],
#        [4],
#        [4],
#        [3],
#        [5],
#        [4],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [4],
#        [4],
#        [3],
#        [5],
#        [5],
#        [3],
#        [4],
#        [4],
#        [3],
#        [4],
#        [4],
#        [3],
#        [3],
#        [4],
#        [3],
#        [4],
#        [2],
#        [3],
#        [3],
#        [3],
#        [5],
#        [3],
#        [2],
#        [2],
#        [4],
#        [5],
#        [3],
#        [3],
#        [3],
#        [4],
#        [3],
#        [4],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [2],
#        [4],
#        [5],
#        [4],
#        [3],
#        [3],
#        [3],
#        [4],
#        [3],
#        [3],
#        [2],
#        [4],
#        [4],
#        [3],
#        [3],
#        [2],
#        [4],
#        [3],
#        [4],
#        [3],
#        [4],
#        [5],
#        [4],
#        [3],
#        [4],
#        [3],
#        [3],
#        [4],
#        [3],
#        [4],
#        [4],
#        [2],
#        [3],
#        [2],
#        [5],
#        [3],
#        [3],
#        [4],
#        [4],
#        [4],
#        [2],
#        [5],
#        [3],
#        [3],
#        [3],
#        [3],
#        [4],
#        [1],
#        [3],
#        [5],
#        [4],
#        [3],
#        [4],
#        [5],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [2],
#        [4],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [4],
#        [4],
#        [3],
#        [5],
#        [3],
#        [3],
#        [2],
#        [3],
#        [4],
#        [4],
#        [2],
#        [4],
#        [5],
#        [4],
#        [3],
#        [4],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [4],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [4],
#        [3],
#        [3],
#        [2],
#        [6],
#        [4],
#        [3],
#        [4],
#        [3]], dtype=int64)

# %%
y
# Out:
# array([[ 221900],
#        [ 538000],
#        [ 180000],
#        [ 604000],
#        [ 510000],
#        [1225000],
#        [ 257500],
#        [ 291850],
#        [ 229500],
#        [ 323000],
#        [ 662500],
#        [ 468000],
#        [ 310000],
#        [ 400000],
#        [ 530000],
#        [ 650000],
#        [ 395000],
#        [ 485000],
#        [ 189000],
#        [ 230000],
#        [ 385000],
#        [2000000],
#        [ 285000],
#        [ 252700],
#        [ 329000],
#        [ 233000],
#        [ 937000],
#        [ 667000],
#        [ 438000],
#        [ 719000],
#        [ 580500],
#        [ 280000],
#        [ 687500],
#        [ 535000],
#        [ 322500],
#        [ 696000],
#        [ 550000],
#        [ 640000],
#        [ 240000],
#        [ 605000],
#        [ 625000],
#        [ 775000],
#        [ 861990],
#        [ 685000],
#        [ 309000],
#        [ 488000],
#        [ 210490],
#        [ 785000],
#        [ 450000],
#        [1350000],
#        [ 228000],
#        [ 345000],
#        [ 600000],
#        [ 585000],
#        [ 920000],
#        [ 885000],
#        [ 292500],
#        [ 301000],
#        [ 951000],
#        [ 430000],
#        [ 650000],
#        [ 289000],
#        [ 505000],
#        [ 549000],
#        [ 425000],
#        [ 317625],
#        [ 975000],
#        [ 287000],
#        [ 204000],
#        [1325000],
#        [1040000],
#        [ 325000],
#        [ 571000],
#        [ 360000],
#        [ 349000],
#        [ 832500],
#        [ 380000],
#        [ 480000],
#        [ 410000],
#        [ 720000],
#        [ 390000],
#        [ 360000],
#        [ 355000],
#        [ 356000],
#        [ 315000],
#        [ 940000],
#        [ 305000],
#        [ 461000],
#        [ 215000],
#        [ 335000],
#        [ 243500],
#        [1099880],
#        [ 153000],
#        [ 430000],
#        [ 700000],
#        [ 905000],
#        [ 247500],
#        [ 199000],
#        [ 314000],
#        [ 437500],
#        [ 850830],
#        [ 555000],
#        [ 699950],
#        [1088000],
#        [ 290000],
#        [ 375000],
#        [ 460000],
#        [ 188500],
#        [ 680000],
#        [ 470000],
#        [ 597750],
#        [ 570000],
#        [ 272500],
#        [ 329950],
#        [ 480000],
#        [ 740500],
#        [ 518500],
#        [ 205425],
#        [ 171800],
#        [ 535000],
#        [ 660000],
#        [ 391500],
#        [ 395000],
#        [ 445000],
#        [ 770000],
#        [1450000],
#        [ 445000],
#        [ 260000],
#        [ 822500],
#        [ 430000],
#        [ 212000],
#        [ 660500],
#        [ 784000],
#        [ 453246],
#        [ 675000],
#        [ 199000],
#        [ 220000],
#        [ 452000],
#        [ 382500],
#        [ 519950],
#        [ 665000],
#        [ 527700],
#        [ 205000],
#        [ 420000],
#        [ 500000],
#        [ 921500],
#        [ 890000],
#        [ 430000],
#        [ 258000],
#        [ 511000],
#        [ 532170],
#        [ 560000],
#        [ 282950],
#        [2250000],
#        [ 350000],
#        [ 215000],
#        [ 650000],
#        [ 320000],
#        [ 247000],
#        [ 320000],
#        [ 255000],
#        [ 438000],
#        [ 900000],
#        [ 441000],
#        [ 420000],
#        [ 370000],
#        [ 269950],
#        [ 807100],
#        [ 653000],
#        [ 371500],
#        [ 284000],
#        [ 272000],
#        [ 313000],
#        [ 917500],
#        [ 673000],
#        [ 425000],
#        [ 399950],
#        [ 385000],
#        [ 269950],
#        [ 330000],
#        [ 260000],
#        [ 470000],
#        [ 589000],
#        [ 163500],
#        [ 835000],
#        [1095000],
#        [ 269000],
#        [ 560000],
#        [ 615000],
#        [ 585188],
#        [ 305000],
#        [ 166950],
#        [ 799000],
#        [ 400000],
#        [ 230000],
#        [ 256883],
#        [ 423000],
#        [ 465000],
#        [ 440000],
#        [ 385000],
#        [ 210000],
#        [ 297000],
#        [ 470000],
#        [ 226500],
#        [ 274250],
#        [ 840000],
#        [ 677900],
#        [ 425000],
#        [ 180250],
#        [ 464000],
#        [ 320000],
#        [ 625504],
#        [ 592500],
#        [ 465000]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split


x_train,x_test,y_train,y_test=train_test_split(X,y,test_size = 0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.xlabel('price')
plt.ylabel('bedrooms')
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,regressor.predict(x_test),color='blue')
plt.xlabel('price')
plt.ylabel('bedrooms')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('data_house.csv')

# %%
data.head()
# Out:
#    Unnamed: 0          id             date   price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900         3       1.00
# 1           1  6414100192  20141209T000000  538000         3       2.25
# 2           2  5631500400  20150225T000000  180000         2       1.00
# 3           3  2487200875  20141209T000000  604000         4       3.00
# 4           4  1954400510  20150218T000000  510000         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  view  condition
# 0         1180      5650     1.0           0     0          3
# 1         2570      7242     2.0           0     0          3
# 2          770     10000     1.0           0     0          3
# 3         1960      5000     1.0           0     0          5
# 4         1680      8080     1.0           0     0          3

# %%
e=data.iloc[:,3:7]
e
# Out:
#       price  bedrooms  bathrooms  sqft_living
# 0    221900         3       1.00         1180
# 1    538000         3       2.25         2570
# 2    180000         2       1.00          770
# 3    604000         4       3.00         1960
# 4    510000         3       2.00         1680
# ..      ...       ...        ...          ...
# 209  464000         6       3.00         2300
# 210  320000         4       2.25         1550
# 211  625504         3       2.25         1270
# 212  592500         4       2.50         2240
# 213  465000         3       2.50         2714
#
# [214 rows x 4 columns]

# %%
e.isna().sum()
# Out:
# price          0
# bedrooms       0
# bathrooms      0
# sqft_living    0
# dtype: int64

# %%
X = e.iloc[:, 1:].round().values.astype(int)
y=e.iloc[:,1].values
X
# Out:
# array([[   3,    1, 1180],
#        [   3,    2, 2570],
#        [   2,    1,  770],
#        [   4,    3, 1960],
#        [   3,    2, 1680],
#        [   4,    4, 5420],
#        [   3,    2, 1715],
#        [   3,    2, 1060],
#        [   3,    1, 1780],
#        [   3,    2, 1890],
#        [   3,    2, 3560],
#        [   2,    1, 1160],
#        [   3,    1, 1430],
#        [   3,    2, 1370],
#        [   5,    2, 1810],
#        [   4,    3, 2950],
#        [   3,    2, 1890],
#        [   4,    1, 1600],
#        [   2,    1, 1200],
#        [   3,    1, 1250],
#        [   4,    2, 1620],
#        [   3,    3, 3050],
#        [   5,    2, 2270],
#        [   2,    2, 1070],
#        [   3,    2, 2450],
#        [   3,    2, 1710],
#        [   3,    2, 2450],
#        [   3,    1, 1400],
#        [   3,    2, 1520],
#        [   4,    2, 2570],
#        [   3,    2, 2320],
#        [   2,    2, 1190],
#        [   4,    2, 2330],
#        [   3,    1, 1090],
#        [   4,    3, 2060],
#        [   3,    2, 2300],
#        [   4,    1, 1660],
#        [   4,    2, 2360],
#        [   4,    1, 1220],
#        [   4,    2, 2620],
#        [   4,    2, 2570],
#        [   4,    2, 4220],
#        [   5,    3, 3595],
#        [   3,    1, 1570],
#        [   3,    1, 1280],
#        [   3,    2, 3160],
#        [   3,    1,  990],
#        [   4,    2, 2290],
#        [   3,    2, 1250],
#        [   3,    2, 2753],
#        [   3,    1, 1190],
#        [   5,    2, 3150],
#        [   3,    2, 1410],
#        [   2,    2, 1980],
#        [   5,    2, 2730],
#        [   4,    2, 2830],
#        [   4,    2, 2250],
#        [   3,    2, 2420],
#        [   5,    3, 3250],
#        [   4,    3, 1850],
#        [   3,    2, 2150],
#        [   3,    2, 1260],
#        [   3,    2, 2519],
#        [   3,    2, 1540],
#        [   3,    2, 1660],
#        [   3,    3, 2770],
#        [   4,    2, 2720],
#        [   4,    2, 2240],
#        [   3,    1, 1000],
#        [   5,    2, 3200],
#        [   5,    3, 4770],
#        [   3,    2, 1260],
#        [   4,    2, 2750],
#        [   4,    2, 2380],
#        [   3,    2, 1790],
#        [   4,    4, 3430],
#        [   4,    2, 1760],
#        [   3,    1, 1040],
#        [   3,    1, 1410],
#        [   4,    2, 3450],
#        [   3,    2, 2350],
#        [   4,    2, 1900],
#        [   2,    1, 2020],
#        [   3,    2, 1680],
#        [   3,    1,  960],
#        [   3,    2, 2140],
#        [   5,    2, 2660],
#        [   3,    3, 2770],
#        [   2,    2, 1610],
#        [   2,    2, 1030],
#        [   4,    2, 1980],
#        [   5,    3, 3520],
#        [   3,    1, 1200],
#        [   3,    2, 1580],
#        [   3,    2, 1580],
#        [   4,    2, 3300],
#        [   3,    2, 1960],
#        [   4,    2, 1160],
#        [   3,    2, 1810],
#        [   3,    2, 2320],
#        [   3,    2, 2070],
#        [   3,    2, 1980],
#        [   3,    2, 2190],
#        [   3,    2, 2920],
#        [   3,    1, 1210],
#        [   3,    2, 2340],
#        [   3,    1, 1670],
#        [   2,    2, 1240],
#        [   4,    2, 3140],
#        [   5,    2, 2030],
#        [   4,    2, 2310],
#        [   3,    2, 1260],
#        [   3,    2, 1540],
#        [   3,    2, 2080],
#        [   4,    2, 3230],
#        [   3,    4, 4380],
#        [   3,    4, 1590],
#        [   2,    1,  880],
#        [   4,    2, 1570],
#        [   4,    1, 1610],
#        [   3,    2, 2400],
#        [   3,    2, 1450],
#        [   2,    1,  770],
#        [   4,    2, 2100],
#        [   3,    2, 2910],
#        [   4,    3, 2750],
#        [   3,    2, 2100],
#        [   4,    2, 2160],
#        [   5,    4, 2320],
#        [   4,    2, 2070],
#        [   3,    2, 1060],
#        [   4,    2, 2010],
#        [   3,    4, 3950],
#        [   3,    2, 2010],
#        [   4,    4, 2140],
#        [   3,    2, 1320],
#        [   4,    2, 2020],
#        [   4,    2, 2590],
#        [   2,    1, 1190],
#        [   3,    2, 1170],
#        [   2,    1, 1110],
#        [   5,    2, 2820],
#        [   3,    1, 1610],
#        [   3,    1, 1060],
#        [   4,    2, 2030],
#        [   4,    2, 3670],
#        [   4,    1, 2550],
#        [   2,    2, 2420],
#        [   5,    2, 2260],
#        [   3,    1, 1430],
#        [   3,    2, 1360],
#        [   3,    1, 1110],
#        [   3,    1, 1250],
#        [   4,    3, 5180],
#        [   1,    1,  700],
#        [   3,    1, 1180],
#        [   5,    4, 3960],
#        [   4,    3, 2640],
#        [   3,    2, 1270],
#        [   4,    2, 1760],
#        [   5,    2, 2060],
#        [   3,    2, 1780],
#        [   3,    2, 3400],
#        [   3,    3, 1910],
#        [   3,    2, 2020],
#        [   3,    2, 1580],
#        [   2,    2, 1340],
#        [   4,    2, 2680],
#        [   3,    2, 2680],
#        [   3,    2, 1370],
#        [   3,    2, 1560],
#        [   3,    2, 2160],
#        [   3,    2, 1340],
#        [   4,    2, 3880],
#        [   4,    2, 2590],
#        [   3,    2, 1120],
#        [   5,    3, 1970],
#        [   3,    1, 1220],
#        [   3,    2, 1950],
#        [   2,    1, 1350],
#        [   3,    2, 1670],
#        [   4,    3, 2380],
#        [   4,    3, 2440],
#        [   2,    2, 1050],
#        [   4,    3, 3130],
#        [   5,    3, 4090],
#        [   4,    2, 1490],
#        [   3,    2, 1900],
#        [   4,    1, 1330],
#        [   3,    2, 2230],
#        [   3,    2, 1650],
#        [   3,    1, 1190],
#        [   3,    2, 2140],
#        [   3,    2, 2180],
#        [   3,    1, 1060],
#        [   3,    2, 1690],
#        [   4,    2, 1970],
#        [   3,    2, 2150],
#        [   3,    2, 1910],
#        [   3,    2, 1350],
#        [   3,    1,  860],
#        [   3,    2, 1940],
#        [   3,    1, 1010],
#        [   3,    2, 1300],
#        [   3,    1,  910],
#        [   4,    2, 2480],
#        [   3,    2, 2440],
#        [   3,    1, 1010],
#        [   2,    1,  900],
#        [   6,    3, 2300],
#        [   4,    2, 1550],
#        [   3,    2, 1270],
#        [   4,    2, 2240],
#        [   3,    2, 2714]])

# %%
y
# Out:
# array([3, 3, 2, 4, 3, 4, 3, 3, 3, 3, 3, 2, 3, 3, 5, 4, 3, 4, 2, 3, 4, 3,
#        5, 2, 3, 3, 3, 3, 3, 4, 3, 2, 4, 3, 4, 3, 4, 4, 4, 4, 4, 4, 5, 3,
#        3, 3, 3, 4, 3, 3, 3, 5, 3, 2, 5, 4, 4, 3, 5, 4, 3, 3, 3, 3, 3, 3,
#        4, 4, 3, 5, 5, 3, 4, 4, 3, 4, 4, 3, 3, 4, 3, 4, 2, 3, 3, 3, 5, 3,
#        2, 2, 4, 5, 3, 3, 3, 4, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 4, 5,
#        4, 3, 3, 3, 4, 3, 3, 2, 4, 4, 3, 3, 2, 4, 3, 4, 3, 4, 5, 4, 3, 4,
#        3, 3, 4, 3, 4, 4, 2, 3, 2, 5, 3, 3, 4, 4, 4, 2, 5, 3, 3, 3, 3, 4,
#        1, 3, 5, 4, 3, 4, 5, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 3, 4, 4, 3,
#        5, 3, 3, 2, 3, 4, 4, 2, 4, 5, 4, 3, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3,
#        3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 2, 6, 4, 3, 4, 3], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 268208744454.20673

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# -387435912886.3657

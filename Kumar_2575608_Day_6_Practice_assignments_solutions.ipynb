# %% [markdown]
# # 1. Write a python program to create a base class "Shape" with methods to calculate area and perimeter. Then, create derived classes "Circle" and "Rectangle" that inherit from the base class and calculate their respective areas and perimeters. Demonstrate their usage in a program.

# %%
import math
class Shape:
    def area(self):
        pass
        
    def perimeter(self):
        pass
    
class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return math.pi*self.radius**2
    def perimeter(self):
        return 2*math.pi*self.radius
    
class Rectangle(Shape):
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        return self.width*self.length
    def perimeter(self):
        return 2*(self.length+self.width)

c=Circle(int(input("enter the radis of the circle: ")))
print("Area of rectangle is :",c.area())
print("perimeter of rectangle is :",c.perimeter())
    
s=Rectangle(int(input("enter the length of the circle: ")),int(input("enter the width of the circle: ")))
print("Area of rectangle is :",s.area())
print("perimeter of rectangle is :",s.perimeter())
# Out:
# enter the radis of the circle: 2
# Area of rectangle is : 12.566370614359172
# perimeter of rectangle is : 12.566370614359172
# enter the length of the circle: 3
# enter the width of the circle: 4
# Area of rectangle is : 12
# perimeter of rectangle is : 14

# %% [markdown]
# # You are developing an online quiz application where users can take quizzes on various topics and receive scores.
#
# 1. Create a class for quizzes and questions.
#
# 2. Implement a scoring system that calculates the user's score on a quiz.
#
# 3. How would you store and retrieve user progress, including quiz history and scores?

# %% [markdown]
# # 2. Write a python script to create a class "Person" with private attributes for age and name. Implement a method to calculate a person's eligibility for voting based on their age. Ensure that age cannot be accessed directly but only through a getter method

# %%
class Person:
    def __init__(self,age,name):
        self.__age=age
        self.__name=name
        
    def get(self):
        return self.__age
    
    def can_vote(self):
        return self.__age >= 18
    
v=Person(55,"Dileep") 
print(f"{v.get()} can vote? {v.can_vote()}")

e=Person(12,"Kumar")
print(f"{e.get()} can vote? {e.can_vote()}")
# Out:
# 55 can vote? True
# 12 can vote? False

# %% [markdown]
# # 3. You are tasked with designing a Python class hierarchy for a simple banking system. The system should be able to handle different types of accounts, such as Savings Accounts and Checking Accounts. Both account types should have common attributes like an account number, account holder's name, and balance. However, Savings Accounts should have an additional attribute for interest rate, while Checking Accounts should have an attribute for overdraft limit.
#
# 1. Create a Python class called Bank Account with the following attributes and methods:
#
# a. Attributes: account number, account holder_name, balance
#
# b. Methods: __init__() (constructor), deposit(), and withdraw()
#
# 2. Create two subclasses, SavingsAccount and Checking Account, that inherit from the BankAccount class.
#
# 3. Add the following attributes and methods to each subclass:
#
# a. Savings Account:
#
# i. Additional attribute: interest_rate
#
# ii. Method: calculate_interest(), which calculates and adds interest to the account based on the interest rate.
#
# b. Checking Account:
#
# i. Additional attribute: overdraft limit
#
# ii. Method: withdraw(), which allows withdrawing money up to the overdraft limit (if available) without additional fees.
#
# 4. Write a program that creates instances of both Savings Account and Checking Account and demonstrates the use of their methods.
#
# 5. Implement proper encapsulation by making the attributes private where necessary and providing getter and setter methods as needed.
#
# 6. Handle any potential errors or exceptions that may occur during operations like withdrawals, deposits, or interest calculations.
#
# 7. Provide comments in your code to explain the purpose of each class, attribute,
#
# and method.
#
# Note: Your code should create instances of the classes, simulate transactions, and
#
# showcase the differences between Savings Accounts and Checking Accounts.

# %%
class BankAccount:
    def __init__(self, account_number, account_holder_name, balance=0):
        self.__account_number = account_number
        self.__account_holder_name = account_holder_name
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            return self.__balance
        else:
            raise ValueError("Amount to deposit should be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            return self.__balance
        else:
            raise ValueError("Invalid withdrawal amount.")

    # Getter methods for private attributes
    def get_balance(self):
        return self.__balance

    def get_account_number(self):
        return self.__account_number

    def get_account_holder_name(self):
        return self.__account_holder_name

# Derived class for savings accounts
class SavingsAccount(BankAccount):
    def __init__(self, account_number, account_holder_name, interest_rate, balance=0):
        super().__init__(account_number, account_holder_name, balance)
        self.__interest_rate = interest_rate

    def calculate_interest(self):
        interest = self.get_balance() * (self.__interest_rate/100)
        self.deposit(interest)
        return interest

# Derived class for checking accounts
class CheckingAccount(BankAccount):
    def __init__(self, account_number, account_holder_name, overdraft_limit, balance=0):
        super().__init__(account_number, account_holder_name, balance)
        self.__overdraft_limit = overdraft_limit

    def withdraw(self, amount):
        if 0 < amount <= (self.get_balance() + self.__overdraft_limit):
            # Adjusted logic here to handle withdrawal within overdraft limit
            new_balance = self.get_balance() - amount
            self._BankAccount__balance = new_balance  # Directly modifying the private attribute
            return new_balance
        else:
            raise ValueError("Withdrawal exceeds available balance and overdraft limit.")

# Demonstration
# Create a savings account with 2% interest
savings = SavingsAccount("SBI11290", "Dileep Kumar", 2, 2000)
print(f"{savings.get_account_holder_name()} Savings Balance: ${savings.get_balance()}")
interest = savings.calculate_interest()
print(f"Interest earned: ${interest}")
print(f"Updated Savings Balance: ${savings.get_balance()}")

# Create a checking account with $100 overdraft limit
checking = CheckingAccount("HDFC234519", "Kumar", 100, 600)
print(f"{checking.get_account_holder_name()} Checking Balance: ${checking.get_balance()}")
checking.withdraw(650)  # This should work because of the overdraft limit
print(f"Updated Checking Balance: ${checking.get_balance()}")
# Out:
# Dileep Kumar Savings Balance: $2000
# Interest earned: $40.0
# Updated Savings Balance: $2040.0
# Kumar Checking Balance: $600
# Updated Checking Balance: $-50

# %% [markdown]
# # 4. You are developing an employee management system for a company. Ensure that the system utilizes encapsulation and polymorphism to handle different types of employees. such as full-time and part-time employees.
#
# 1. Create a base class called "Employee" with private attributes for name, employee ID, and salary. Implement getter and setter methods for these attributes.
#
# 2. Design two subclasses, "FullTimeEmployee" and "PartTimeEmployee," that inherit from "Employee." These subclasses should encapsulate specific properties like hours worked (for part-time employees) and annual salary (for full-time employees).
#
# 3. Override the salary calculation method in both subclasses to account for different payment structures.
#
# 4. Write a program that demonstrates polymorphism by creating instances of both "Full TimeEmployee" and "PartTimeEmployee." Calculate their salaries and display employee information.

# %%
# Base class for employees
class Employee:
    def __init__(self, name, emp_id, salary=0):
        self.__name = name
        self.__emp_id = emp_id
        self.__salary = salary

    @property
    def name(self):
        return self.__name

    @name.setter
    def name(self, value):
        self.__name = value

    @property
    def emp_id(self):
        return self.__emp_id

    @emp_id.setter
    def emp_id(self, value):
        self.__emp_id = value

    @property
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self, value):
        if value >= 0:
            self.__salary = value
        else:
            raise ValueError("Salary cannot be negative.")

    def calculate_salary(self):
        return self.__salary

    def display_info(self):
        return f"Employee ID: {self.__emp_id}, Name: {self.__name}, Salary: ${self.calculate_salary():.2f}"

# Subclass for full-time employees
class FullTimeEmployee(Employee):
    def __init__(self, name, emp_id, annual_salary):
        super().__init__(name, emp_id)
        self.__annual_salary = annual_salary

    def calculate_salary(self):
        # For a full-time employee, just return the annual salary
        return self.__annual_salary

# Subclass for part-time employees
class PartTimeEmployee(Employee):
    def __init__(self, name, emp_id, hourly_rate, hours_worked):
        super().__init__(name, emp_id)
        self.__hourly_rate = hourly_rate
        self.__hours_worked = hours_worked

    def calculate_salary(self):
        # For a part-time employee, the salary is hourly_rate * hours_worked
        return self.__hourly_rate * self.__hours_worked

# Demonstrate polymorphism
employees = [
    FullTimeEmployee("Dileep ", "12875", 60000),  # Annual Salary of $60,000
    PartTimeEmployee("Kumar", "1290", 20, 50)  # $20/hr and worked 50 hours
]

for emp in employees:
    print(emp.display_info())
# Out:
# Employee ID: 12875, Name: Dileep , Salary: $60000.00
# Employee ID: 1290, Name: Kumar, Salary: $1000.00

# %% [markdown]
# # 5. Library Management System-Scenario: You are developing a library management system
#
# where you need to handle books, patrons, and library transactions.
#
# ED Info
#
#
#
# 1. Create a class hierarchy that includes classes for books (e.g., Book), patrons (e.g.. Patron), and transactions (e.g., Transaction). Define attributes and methods for each class.
#
# 2. Implement encapsulation by making relevant attributes private and providing getter and setter methods where necessary. T
#
# 3. Use inheritance to represent different types of books (e.g., fiction, non-fiction) as subclasses of the Book class. Ensure that each book type can have specific attributes and methods.
#
# 4. Demonstrate polymorphism by allowing patrons to check out and return books,
#
# regardless of the book type. 5. Implement a method for tracking overdue books and notifying patrons.
#
# 6. Consider scenarios like book reservations, late fees, and library staff interactions in your design.

# %%
from datetime import datetime, timedelta

# 1. Classes

class Book:
    def __init__(self, title, author, isbn):
        self.__title = title
        self.__author = author
        self.__isbn = isbn
        
    # 2. Encapsulation
    def get_title(self):
        return self.__title
    
    def get_author(self):
        return self.__author

    def get_isbn(self):
        return self.__isbn


class Fiction(Book):
    def __init__(self, title, author, isbn, genre):
        super().__init__(title, author, isbn)
        self.__genre = genre

    def get_genre(self):
        return self.__genre


class NonFiction(Book):
    def __init__(self, title, author, isbn, field):
        super().__init__(title, author, isbn)
        self.__field = field

    def get_field(self):
        return self.__field


class Patron:
    def __init__(self, name, id):
        self.__name = name
        self.__id = id
        self.__checked_out_books = []

    def checkout_book(self, book):
        # 4. Polymorphism
        if isinstance(book, Book):
            self.__checked_out_books.append(book)
            return f"{book.get_title()} has been checked out."
        return "Invalid book type."

    def return_book(self, book):
        if book in self.__checked_out_books:
            self.__checked_out_books.remove(book)
            return f"{book.get_title()} has been returned."
        return "You did not check out this book."

    def get_overdue_books(self, transactions):
        overdue_books = []
        for transaction in transactions:
            if transaction.get_patron_id() == self.__id and transaction.is_overdue():
                overdue_books.append(transaction.get_book())
        return overdue_books


class Transaction:
    def __init__(self, patron_id, book, due_date):
        self.__patron_id = patron_id
        self.__book = book
        self.__due_date = due_date

    def get_patron_id(self):
        return self.__patron_id

    def get_book(self):
        return self.__book

    def is_overdue(self):
        return datetime.now() > self.__due_date

    def set_due_date(self, new_due_date):
        self.__due_date = new_due_date
        return f"Due date set to {self.__due_date}"

    # 6. Additional Scenarios
    def calculate_late_fee(self):
        if self.is_overdue():
            overdue_days = (datetime.now() - self.__due_date).days
            return overdue_days * 1  # Let's say $1 per overdue day.
        return 0


# Demonstration
book1 = Fiction("Harry Potter", "J.K. Rowling", "123456789", "Fantasy")
book2 = NonFiction("Cosmos", "Carl Sagan", "987654321", "Science")

patron = Patron("John Doe", "001")

# Patron checks out and returns a book
print(patron.checkout_book(book1))
print(patron.checkout_book(book2))
print(patron.return_book(book1))

# Overdue book scenario
transaction1 = Transaction(patron_id="001", book=book1, due_date=datetime.now() - timedelta(days=5))
transaction2 = Transaction(patron_id="001", book=book2, due_date=datetime.now() + timedelta(days=5))

transactions = [transaction1, transaction2]

print(f"Overdue books: {[book.get_title() for book in patron.get_overdue_books(transactions)]}")
print(f"Late fee for book1: ${transaction1.calculate_late_fee()}")
# Out:
# Harry Potter has been checked out.
# Cosmos has been checked out.
# Harry Potter has been returned.
# Overdue books: ['Harry Potter']
# Late fee for book1: $5

# %% [markdown]
# # 6.Online Shopping Cart
#
# Scenario: You are tasked with designing a class hierarchy for an online shopping cart system. The system should handle products, shopping carts, and orders. Consider various OOP principles while designing this system.
#
# 1. Create a class hierarchy that includes classes for products (e.g., Product), shopping carts (e.g., ShoppingCart), and orders (e.g., Order). Define attributes and methods for each class.
#
# 2. Implement encapsulation by making relevant attributes private and providing getter and setter methods where necessary.
#
# 3. Use inheritance to represent different types of products (e.g., electronics, clothing) as subclasses of the Product class. Ensure that each product type can have specific attributes and methods.
#
# 4. Demonstrate polymorphism by allowing various product types to be added to a shopping cart and calculate the total cost of items in the cart.
#
# 5. Implement a method for placing an order, which transfers items from the shopping cart to an order.
#
# Consider scenarios like out-of-stock products, discounts, and shipping costs in your design.

# %%
class Product:
    def __init__(self, name, price, quantity_in_stock):
        self.__name = name
        self.__price = price
        self.__quantity_in_stock = quantity_in_stock

    def get_name(self):
        return self.__name

    def get_price(self):
        return self.__price

    def decrease_stock(self, quantity):
        if self.__quantity_in_stock - quantity >= 0:
            self.__quantity_in_stock -= quantity
        else:
            raise ValueError("Not enough stock.")

    def is_in_stock(self):
        return self.__quantity_in_stock > 0


class Electronics(Product):
    def __init__(self, name, price, quantity_in_stock, warranty_period):
        super().__init__(name, price, quantity_in_stock)
        self.__warranty_period = warranty_period

    def get_warranty_period(self):
        return self.__warranty_period


class Clothing(Product):
    def __init__(self, name, price, quantity_in_stock, size):
        super().__init__(name, price, quantity_in_stock)
        self.__size = size

    def get_size(self):
        return self.__size


class ShoppingCart:
    def __init__(self):
        self.__items = {}

    def add_product(self, product, quantity=1):
        if product.is_in_stock():
            if product in self.__items:
                self.__items[product] += quantity
            else:
                self.__items[product] = quantity
            product.decrease_stock(quantity)
        else:
            print(f"{product.get_name()} is out of stock.")

    def total_cost(self):
        return sum(product.get_price() * quantity for product, quantity in self.__items.items())

    def checkout(self):
        if self.__items:
            return Order(self)
        else:
            print("Your cart is empty.")
            return None


class Order:
    def __init__(self, cart):
        self.__items = cart._ShoppingCart__items
        self.__total_cost = cart.total_cost()

    def get_order_details(self):
        item_details = ", ".join(f"{product.get_name()} (x{quantity})" for product, quantity in self.__items.items())
        return f"Order Items: {item_details}, Total Cost: ${self.__total_cost:.2f}"


# Demonstration:
shirt = Clothing("Cool T-Shirt", 20.0, 5, "M")
phone = Electronics("iPhone", 1000.0, 2, "2 years")

cart = ShoppingCart()
cart.add_product(shirt, 2)
cart.add_product(phone)

print(f"Total cost: ${cart.total_cost():.2f}")

order = cart.checkout()
if order:
    print(order.get_order_details())
# Out:
# Total cost: $1040.00
# Order Items: Cool T-Shirt (x2), iPhone (x1), Total Cost: $1040.00

# %%
# %matplotlib inline
import pandas as pd

titles=pd.read_csv("titles.csv")

titles
# Out:
#                                       title  year
# 0                        Tasveer Mere Sanam  1996
# 1                                  Only You  1994
# 2                      El pueblo del terror  1970
# 3                                   Machine  2007
# 4                                      MARy  2008
# ...                                     ...   ...
# 244909  Black Butterfly in a Colorful World  2018
# 244910        Hua fei hua wu chun man cheng  1980
# 244911                 Nippon dabi katsukyu  1970
# 244912        Under Siege 2: Dark Territory  1995
# 244913            She Must Be Seeing Things  1987
#
# [244914 rows x 2 columns]

# %% [markdown]
# # How many movies are listed in the titles dataframe?

# %%
num_movies=titles.shape[0]
print(f"The number of movies listed in titles is {num_movies}")
# Out:
# The number of movies listed in titles is 244914

# %% [markdown]
# # What are the earliest two films listed in the titles dataframe?

# %%
two_films=titles.sort_values("year",ascending=False)
t=two_films.head(2)["title"]
print("The two earliest films listed in titles dataframe is :\n")
for title in t:
    print(title)
# Out:
# The two earliest films listed in titles dataframe is :
#
# 100 Years
# The Zero Century: Maetel

# %% [markdown]
# # How many movies have the title "Hamlet"?

# %%
hamlet_mvies=titles[titles["title"]=="Hamlet"]
print("The number of movies have title 'Hamlet' is : ",hamlet_mvies.shape[0])
# Out:
# The number of movies have title 'Hamlet' is :  20

# %% [markdown]
# # How many movies are titled "North by Northwest"?

# %%
North_by_Northwest=titles[titles["title"]=="North by Northwest"].shape[0]
print("The number of movies are titled 'North by Northwest' is :",North_by_Northwest)
# Out:
# The number of movies are titled 'North by Northwest' is : 1

# %% [markdown]
# # When was the first movie titled "Hamlet" made?

# %%
Hamlet_made=titles[titles["title"]=="Hamlet"]
d=Hamlet_made.sort_values("year")
print("The first movie titles 'Hamlet' made in ",d.head(1)["year"].values[0])
# Out:
# The first movie titles 'Hamlet' made in  1910

# %% [markdown]
# # List all of the "Treasure Island" movies from earliest to most recent

# %%
Treasure=titles[titles["title"]=="Treasure Island"]
d=Treasure.sort_values("year")
d
# Out:
#                   title  year
# 55686   Treasure Island  1918
# 196514  Treasure Island  1920
# 141822  Treasure Island  1934
# 77354   Treasure Island  1950
# 65051   Treasure Island  1972
# 37238   Treasure Island  1973
# 173051  Treasure Island  1985
# 27076   Treasure Island  1999

# %% [markdown]
# # How many movies were made in the year 1950?

# %%
movie_1950=titles[titles["year"]==1950].shape[0]
print(movie_1950,"movies are made in the year 1950")
# Out:
# 1113 movies are made in the year 1950

# %% [markdown]
# # How many movies were made in the year 1960?

# %%
movie_1960=titles[titles["year"]==1960].shape[0]
print(movie_1960,"movies are made in the year 1950")
# Out:
# 1549 movies are made in the year 1950

# %% [markdown]
# # How many movies were made from 1950 through 1959?

# %%
movies_1950s=titles[(titles["year"]>=1950 ) & (titles["year"]<1959)].shape[0]
print(movies_1950s,"Movies were made from 1950 through 1959")
# Out:
# 11419 Movies were made from 1950 through 1959

# %% [markdown]
# # In what years has a movie titled "Batman" been released?

# %%
Batman=titles[titles["title"]=="Batman"]
years=Batman["year"]
output_years = ', '.join(map(str, years.tolist()))
print(f"In the years {output_years} a movie titled 'Batman' has been released.")
# Out:
# In the years 1943, 1989 a movie titled 'Batman' has been released.

# %% [markdown]
# # How many roles were there in the movie "Inception"?

# %%
import pandas as pd
cast=pd.read_csv("cast.csv")
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
inception_cast = cast[cast["title"] == "Inception"]

# Count the unique roles
num_roles = inception_cast["name"].nunique()  

print(f"There were {num_roles} unique roles in the movie 'Inception'.")
# Out:
# There were 78 unique roles in the movie 'Inception'.

# %% [markdown]
# # How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
inception_cast = cast[cast["title"] == "Inception"]

# Count roles that do NOT have an "n" value
num_roles_without_n = inception_cast["n"].isna().sum()

print(f"There were {num_roles_without_n} roles in 'Inception' that are NOT ranked by an 'n' value.")
# Out:
# There were 27 roles in 'Inception' that are NOT ranked by an 'n' value.

# %% [markdown]
# # But how many roles in the movie "Inception" did receive an "n" value?

# %%
inception_cast = cast[cast["title"] == "Inception"]

num_roles_with_n = inception_cast["n"].notna().sum()

print(f"There were {num_roles_with_n} roles in 'Inception' that did receive an 'n' value.")
# Out:
# There were 51 roles in 'Inception' that did receive an 'n' value.

# %% [markdown]
# # Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
nbn_cast = cast[(cast["title"] == "North by Northwest") & (cast['n'].notna())]

sorted_nbn_cast = nbn_cast.sort_values("n")
print(sorted_nbn_cast[["name","n"]])
# Out:
#                          name     n
# 871426             Cary Grant   1.0
# 3518333       Eva Marie Saint   2.0
# 1457165           James Mason   3.0
# 3157232   Jessie Royce Landis   4.0
# 356707         Leo G. Carroll   5.0
# 3048272  Josephine Hutchinson   6.0
# 1695173           Philip Ober   7.0
# 1275337         Martin Landau   8.0
# 2447081         Adam Williams   9.0
# 1811387          Edward Platt  10.0
# 665768      Robert Ellenstein  11.0
# 2295714          Les Tremayne  12.0
# 464736        Philip Coolidge  13.0
# 1508344         Patrick McVey  14.0
# 206471           Edward Binns  15.0
# 1384780             Ken Lynch  16.0

# %% [markdown]
# # Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
nbn_cast = cast[(cast["title"] == "Sleuth") & (cast["year"]==1972)]

sorted_nbn_cast = nbn_cast.sort_values("n")
print(sorted_nbn_cast[["name","n"]])
# Out:
#                        name    n
# 1705394    Laurence Olivier  1.0
# 326773        Michael Caine  2.0
# 373876       Alec Cawthorne  3.0
# 1465483  John (II) Matthews  4.0
# 2724553  Eve (III) Channing  5.0
# 1448690        Teddy Martin  6.0

# %% [markdown]
# # Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
nbn_cast = cast[(cast["title"] == "Sleuth") & (cast["year"]==2007)]

sorted_nbn_cast = nbn_cast.sort_values("n")
print(sorted_nbn_cast[["name","n"]])
# Out:
#                         name    n
# 326774         Michael Caine  1.0
# 1293634             Jude Law  2.0
# 1805907        Harold Pinter  3.0
# 260242       Kenneth Branagh  NaN
# 373877   Alec (II) Cawthorne  NaN
# 2724552    Eve (II) Channing  NaN
# 3370424    Carmel O'Sullivan  NaN

# %% [markdown]
# # How many roles were credited in the silent 1921 version of Hamlet?

# %%
hamlet_1921 = cast[(cast["title"] == "Hamlet") & (cast["year"] == 1921)]

num_roles_1921 = len(hamlet_1921)

print(f"There were {num_roles_1921} roles credited in the silent 1921 version of 'Hamlet'.")
# Out:
# There were 9 roles credited in the silent 1921 version of 'Hamlet'.

# %% [markdown]
# # How many roles were credited in Branagh's 1996 Hamlet?

# %%
hamlet_1996 = cast[(cast["title"] == "Hamlet") & (cast["year"] == 1996)]
num_roles_1996 = len(hamlet_1996)
print(f"There were {num_roles_1996} roles credited in the silent 1996 version of 'Hamlet'.")
# Out:
# There were 54 roles credited in the silent 1996 version of 'Hamlet'.

# %% [markdown]
# # How many "Hamlet" roles have been listed in all film credits through history?

# %%
hamlet_roles = cast[cast["title"] == "Hamlet"]
num_roles_hamlet=len(hamlet_roles)
print(f"There were {num_roles_hamlet} roles have been listed in all film creidts through histroy 'Hamlet'.")
# Out:
# There were 342 roles have been listed in all film creidts through histroy 'Hamlet'.

# %% [markdown]
# # How many people have played an "Ophelia"?

# %%
ophelia=cast[cast["character"]=="Ophelia"]
unique_ophelias=ophelia["character"].nunique()
print(f"{unique_ophelias} people have played an 'Ophelia'.")
# Out:
# 1 people have played an 'Ophelia'.

# %% [markdown]
# # How many people have played a role called "The Dude"?

# %%
Dude=cast[cast["character"]=="The Dude"]

unique_dude=Dude["character"].nunique()
print(f"{unique_dude} people have played an 'The Dude'.")
# Out:
# 1 people have played an 'The Dude'.

# %% [markdown]
# # How many people have played a role called "The Stranger"?

# %%
stranger=cast[cast["character"]=="The Stranger"]

print(f"{stranger.shape[0]} people have played an 'The Stranger'.")
# Out:
# 212 people have played an 'The Stranger'.

# %% [markdown]
# # How many roles has Sidney Poitier played throughout his career?

# %%
sidney = cast[cast['name'] == "Sidney Poitier"]

# Getting unique roles or characters played by Sidney Poitier
unique_roles = sidney['character'].unique()

# Counting the number of unique roles
num_unique_roles = len(unique_roles)

print(f"There are {num_unique_roles} roles that 'Sidney Poitier' has played throughout his career.")
# Out:
# There are 41 roles that 'Sidney Poitier' has played throughout his career.

# %% [markdown]
# # How many roles has Judi Dench played?

# %%
sidney = cast[cast['name'] == "Judi Dench"]

# Getting unique roles or characters played by Sidney Poitier
unique_roles = sidney['character'].unique()

# Counting the number of unique roles
num_unique_roles = len(unique_roles)

print(f"There are {num_unique_roles} roles that 'Judi Dench' has played throughout his career.")
# Out:
# There are 46 roles that 'Judi Dench' has played throughout his career.

# %% [markdown]
# # List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
# Assuming you have a DataFrame named cast with columns "name", "year", "n", and "character"
cary_grant_supporting_roles = cast[
    (cast['name'] == "Cary Grant") & 
    (cast['n'] == 2) & 
    (cast['year'] >= 1940) & 
    (cast['year'] < 1950)
]

# Sorting by year
sorted_roles = cary_grant_supporting_roles.sort_values('year')

# Display the results
for _, row in sorted_roles.iterrows():
    print(f"In {row['year']}, Cary Grant played the supporting role of '{row['character']}' in the movie '{row['title']}'.")
# Out:
# In 1940, Cary Grant played the supporting role of 'Nick Arden' in the movie 'My Favorite Wife'.
# In 1941, Cary Grant played the supporting role of 'Roger Adams' in the movie 'Penny Serenade'.

# %% [markdown]
# # List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
# Assuming you have a DataFrame named cast with columns "name", "year", "n", and "character"
cary_grant_leading_roles = cast[
    (cast['name'] == "Cary Grant") & 
    (cast['n'] == 1) & 
    (cast['year'] >= 1940) & 
    (cast['year'] < 1950)
]

# Sorting by year
sorted_leading_roles = cary_grant_leading_roles.sort_values('year')

# Display the results
for _, row in sorted_leading_roles.iterrows():
    print(f"In {row['year']}, Cary Grant played the leading role of '{row['character']}' in the movie '{row['title']}'.")
# Out:
# In 1940, Cary Grant played the leading role of 'Matt Howard' in the movie 'The Howards of Virginia'.
# In 1940, Cary Grant played the leading role of 'Walter Burns' in the movie 'His Girl Friday'.
# In 1940, Cary Grant played the leading role of 'C. K. Dexter Haven' in the movie 'The Philadelphia Story'.
# In 1941, Cary Grant played the leading role of 'Johnnie Aysgarth' in the movie 'Suspicion'.
# In 1942, Cary Grant played the leading role of 'Leopold Dilg' in the movie 'The Talk of the Town'.
# In 1942, Cary Grant played the leading role of 'Patrick 'Pat' O'Toole' in the movie 'Once Upon a Honeymoon'.
# In 1943, Cary Grant played the leading role of 'Capt. Cassidy' in the movie 'Destination Tokyo'.
# In 1943, Cary Grant played the leading role of 'Joe Adams -posing as Joe Bascopolous' in the movie 'Mr. Lucky'.
# In 1944, Cary Grant played the leading role of 'Jerry Flynn' in the movie 'Once Upon a Time'.
# ...

# %% [markdown]
# # How many roles were available for actors in the 1950s?

# %%
roles_actors=cast[(cast['type']=='actor') & (cast["year"]>=1950) & (cast["year"]<=1960)]
num_roles=len(roles_actors)
print(f"There were {num_roles} roles available for actors in the 1950s.")
# Out:
# There were 171302 roles available for actors in the 1950s.

# %% [markdown]
# # How many roles were available for actresses in the 1950s?

# %%
roles_actors=cast[(cast['type']=='actress') & (cast["year"]>=1950) & (cast["year"]<=1960)]
num_roles=len(roles_actors)
print(f"There were {num_roles} roles available for actresses in the 1950s.")
# Out:
# There were 63333 roles available for actresses in the 1950s.

# %% [markdown]
# # How many leading roles in 11 were available from the beginning of film history through 13802

# %%
# Assuming you want to check until the year 1980
leading_roles = cast[(cast['n'] == 1) & (cast['year'] <= 1980)]
num_leading_roles = len(leading_roles)

print(f"There were {num_leading_roles} leading roles available from the beginning of film history through 1980.")
# Out:
# There were 65140 leading roles available from the beginning of film history through 1980.

# %% [markdown]
# # How many non-leading roles were available through from the beginning of film history through 1980

# %%
# Filtering for non-leading roles up to the year 1980
non_leading_roles = cast[(cast['n'] != 1) & (cast['year'] <= 1980)]

# Counting the number of non-leading roles
num_non_leading_roles = len(non_leading_roles)

print(f"There were {num_non_leading_roles} non-leading roles available from the beginning of film history through 1980.")
# Out:
# There were 1117667 non-leading roles available from the beginning of film history through 1980.

# %% [markdown]
# # How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
# Filtering for roles up to 1980 without an 'n' value
unranked_roles = cast[(cast['n'].isna()) & (cast['year'] <= 1980)]

# Counting the number of these roles
num_unranked_roles = len(unranked_roles)

print(f"There were {num_unranked_roles} roles through 1980 that were minor enough they did not warrant a numeric 'n' rank.")
# Out:
# There were 448347 roles through 1980 that were minor enough they did not warrant a numeric 'n' rank.

# %% [markdown]
# # What are the ten most common movie names of all time?

# %%
# Counting the occurrences of each movie title
movie_counts = titles["title"].value_counts()

# Getting the top 10 most common movie names
top_10_movies = movie_counts.head(10)

print(top_10_movies)
# Out:
# title
# Hamlet                  20
# Carmen                  17
# Macbeth                 16
# Temptation              12
# The Outsider            12
# Maya                    12
# Honeymoon               11
# The Three Musketeers    11
# Freedom                 11
# Othello                 11
# Name: count, dtype: int64

# %%
# Filtering for movies from the 1930s
movies_1930s = titles[(titles["year"] >= 1930) & (titles["year"] < 1940)]

# Counting movies released in each year
yearly_counts = movies_1930s["year"].value_counts()

# Getting the top 3 years with the most films released
top_3_years = yearly_counts.head(3)

print(top_3_years)
# Out:
# year
# 1937    1224
# 1936    1169
# 1938    1163
# Name: count, dtype: int64

# %% [markdown]
# # Plot the number of films that have been released each decade over the history of cinema.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named titles with a column "year"
# Create a new column for the decade
titles['decade'] = (titles['year'] // 10) * 10

# Group by the decade and count the number of films
decade_counts = titles.groupby('decade').size()

# Plotting
decade_counts.plot(kind='bar', figsize=(10, 6))
plt.title("Number of Films Released Each Decade")
plt.xlabel("Decade")
plt.ylabel("Number of Films")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the number of "Hamlet" films made each decade.

# %%
import matplotlib.pyplot as plt

titles_hamlet=titles[titles["title"]=="Hamlet"]

titles_hamlet['decade']=(titles_hamlet['year'] // 10) * 10

decade_counts=titles_hamlet.groupby('decade').size()

decade_counts.plot(kind="bar",figsize=(10,6))
plt.title("Number of 'Hamlet' films made each decade ")

plt.xlabel("Decade")

plt.ylabel("Number of films")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\2022251084.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titles_hamlet['decade']=(titles_hamlet['year'] // 10) * 10

# %% [markdown]
# # Plot the number of "Rustler" characters in each decade of the history of film.

# %%
import matplotlib.pyplot as plt

rustlers=cast[cast["character"]=="Rustler"]
rustlers['decade']=(rustlers["year"]//10) * 10

decade_counts=rustlers.groupby('decade').size()

decade_counts.plot(kind="bar",figsize=(10,6))
plt.title("Rustler character in each decade of the histroy of film")
plt.xlabel("Decade")
plt.ylabel("number of films")
plt.grid(axis="y")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\1199596442.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rustlers['decade']=(rustlers["year"]//10) * 10

# %% [markdown]
# # Plot the number of "Hamlet" characters each decade.

# %%
hamlet_c=cast[cast["character"]=="Hamlet"]
hamlet_c['decade']=(hamlet_c['year']//10)*10
hamlet_c_d=hamlet_c.groupby('decade').size()
hamlet_c_d.plot(kind="bar",figsize=(10,6))
plt.title("number of 'Hamlet' characters each decade.")
plt.xlabel("Decade")
plt.ylabel("Number of films")
plt.grid(axis="y")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\2728479563.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hamlet_c['decade']=(hamlet_c['year']//10)*10

# %% [markdown]
# # What are the 11 most common character names in movie history?

# %%
char_counts = cast["character"].value_counts()
top_10_char = char_counts.head(11)
print(top_10_char)
# Out:
# character
# Himself        20746
# Dancer         12477
# Extra          11948
# Reporter        8434
# Student         7773
# Doctor          7669
# Party Guest     7245
# Policeman       7029
# Nurse           6999
# Bartender       6802
# Herself         6705
# Name: count, dtype: int64

# %% [markdown]
# # Who are the 10 people most often credited as "Herself" in film history?

# %%
char_counts = cast[cast["character"]=="Herself"]
herself_counts=char_counts['name'].value_counts()
print(herself_counts.head(10))
# Out:
# name
# Queen Elizabeth II           12
# Joyce Brothers                9
# Luisa Horga                   9
# Mar?a Luisa (V) Mart?n        9
# Margaret Thatcher             8
# Hillary Clinton               8
# In?s J. Southern              6
# Mar?a Isabel (III) Mart?n     6
# Marta Berrocal                6
# Sumie Sakai                   6
# Name: count, dtype: int64

# %% [markdown]
# # Who are the 10 people most often credited as "Himself" in film history?

# %%
char_counts=cast[cast["character"]=="Himself"]
char_names=char_counts['name'].value_counts().head(10)
print(char_names)
# Out:
# name
# Adolf Hitler             99
# Richard Nixon            44
# Ronald Reagan            41
# John F. Kennedy          37
# George W. Bush           25
# Winston Churchill        24
# Martin Luther King       23
# Ron Jeremy               22
# Bill Clinton             22
# Franklin D. Roosevelt    21
# Name: count, dtype: int64

# %% [markdown]
# # Which actors or actresses appeared in the most movies in the year 1945

# %%
a_act=cast[cast["year"]==1945]
names=a_act["name"].value_counts()
print(names.head(1))
# Out:
# name
# Emmett Vogan    39
# Name: count, dtype: int64

# %% [markdown]
# # Which actors or actresses appeared in the most movies in the year 1985

# %%
a_act=cast[cast["year"]==1985]
names=a_act["name"].value_counts()
print(names.head(1))
# Out:
# name
# Mammootty    22
# Name: count, dtype: int64

# %% [markdown]
# # Plot how many roles Mammootty has played in each year of his career.

# %%
mam_char=cast[cast["name"]=="Mammootty"]

mam_year=mam_char.groupby("year").size()
mam_year.plot(kind="bar",figsize=(10,6))
plt.title("Roles Mammootty has played in each year of his career")
plt.xlabel("Year")
plt.ylabel("Number of roles")
plt.tight_layout()
plt.grid(axis="y")
plt.show()

# %% [markdown]
# # What are the 10 most frequent roles that start with the phrase "Patron in"?

# %%
# Replace NaN with a placeholder string and then filter
patron_roles = cast[cast['character'].fillna('').str.startswith("Patron in")]

# Counting occurrences of each role name
top_patron_roles = patron_roles['character'].value_counts().head(10)

print(top_patron_roles)
# Out:
# character
# Patron in Frisky Rabbit         16
# Patron in Chinese Restaurant     9
# Patron in the Coffee House       9
# Patron in Billiard Parlor        5
# Patron in restaurant             4
# Patron in Bar                    4
# Patron in cabaret                3
# Patron in Restaurant             3
# Patron in Club                   3
# Patron in booth                  2
# Name: count, dtype: int64

# %% [markdown]
# # What are the 10 most frequent roles that start with the word "Science"?

# %%
sc=cast[cast["character"].fillna('').str.startswith("Science")]
science_fre=sc['character'].value_counts().head(10)
print(science_fre)
# Out:
# character
# Science Teacher         60
# Science Student          9
# Science Fair Student     9
# Science Fair Judge       6
# Science Fair Kid         5
# Science Reporter         5
# Science Kid              5
# Science Club Member      5
# Science Promo Cadet      5
# Science                  4
# Name: count, dtype: int64

# %% [markdown]
# # Plot the n-values of the roles that Judi Dench has played over her career.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter rows for Judi Dench
judi_dench = cast[cast['name'] == 'Judi Dench']

# Sort by year
judi_dench_sorted = judi_dench.sort_values(by='year')

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(judi_dench_sorted['year'], judi_dench_sorted['n'], marker='o', linestyle='-')
plt.title("Judi Dench's Role n-values Over Her Career")
plt.xlabel("Year")
plt.ylabel("n-value")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the n-values of Cary Grant's roles through his career.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter rows for Cary Grant
cary_grant = cast[cast['name'] == 'Cary Grant']

# Sort by year
cary_grant_sorted = cary_grant.sort_values(by='year')

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(cary_grant_sorted['year'], cary_grant_sorted['n'], marker='o', linestyle='-')
plt.title("Cary Grant's Role n-values Over His Career")
plt.xlabel("Year")
plt.ylabel("n-value")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the n-value of the roles that Sidney Poitier has acted over the years.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter rows for Sidney Poitier
sidney_poitier = cast[cast['name'] == 'Sidney Poitier']

# Sort by year
sidney_poitier_sorted = sidney_poitier.sort_values(by='year')

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(sidney_poitier_sorted['year'], sidney_poitier_sorted['n'], marker='o', linestyle='-')
plt.title("Sidney Poitier's Role n-values Over the Years")
plt.xlabel("Year")
plt.ylabel("n-value")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %%
# Assuming you have a DataFrame named cast with columns "type", "year", and "n"

# Filtering for leading roles in the 1950s for actors
leading_actor_roles = cast[(cast['type'] == 'actor') & (cast['n'] == 1) & (cast['year'] >= 1950) & (cast['year'] < 1960)]

# Filtering for leading roles in the 1950s for actresses
leading_actress_roles = cast[(cast['type'] == 'actress') & (cast['n'] == 1) & (cast['year'] >= 1950) & (cast['year'] < 1960)]

# Counting the number of roles
num_actor_roles = len(leading_actor_roles)
num_actress_roles = len(leading_actress_roles)

print(f"Number of leading roles for actors in the 1950s: {num_actor_roles}")
print(f"Number of leading roles for actresses in the 1950s: {num_actress_roles}")
# Out:
# Number of leading roles for actors in the 1950s: 6692
# Number of leading roles for actresses in the 1950s: 3040

# %% [markdown]
# # How many supporting (n=2) roles were available to actors, and how many to actresses, in the 1950s?

# %%
# Assuming you have a DataFrame named cast with columns "type", "year", and "n"

# Filtering for supporting roles in the 1950s for actors
supporting_actor_roles = cast[(cast['type'] == 'actor') & (cast['n'] == 2) & (cast['year'] >= 1950) & (cast['year'] < 1960)]

# Filtering for supporting roles in the 1950s for actresses
supporting_actress_roles = cast[(cast['type'] == 'actress') & (cast['n'] == 2) & (cast['year'] >= 1950) & (cast['year'] < 1960)]

# Counting the number of roles
num_actor_roles = len(supporting_actor_roles)
num_actress_roles = len(supporting_actress_roles)

print(f"Number of supporting roles for actors in the 1950s: {num_actor_roles}")
print(f"Number of supporting roles for actresses in the 1950s: {num_actress_roles}")
# Out:
# Number of supporting roles for actors in the 1950s: 4640
# Number of supporting roles for actresses in the 1950s: 4635

# %% [markdown]
# # Using groupby(), plot the number of films that have been released each decade in the history of cinema.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named titles with a column "year"
titles['decade'] = (titles['year'] // 10) * 10

# Group by the decade and count unique films
films_per_decade = titles.groupby('decade')['title'].nunique()

# Plotting
films_per_decade.plot(kind="bar", figsize=(10,6))
plt.title("Number of Films Released Each Decade")
plt.xlabel("Decade")
plt.ylabel("Number of Films")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Use groupby() to plot the number of "Hamlet" films made each decade.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named titles with a column "title" and "year"

# Filter for "Hamlet" films
hamlet_films = titles[titles['title'] == "Hamlet"]

# Create a new column for the decade
hamlet_films['decade'] = (hamlet_films['year'] // 10) * 10

# Group by the decade and count the number of films
films_per_decade = hamlet_films.groupby('decade').size()

# Plotting
films_per_decade.plot(kind="bar", figsize=(10,6))
plt.title("Number of 'Hamlet' Films Made Each Decade")
plt.xlabel("Decade")
plt.ylabel("Number of Films")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\2861004188.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hamlet_films['decade'] = (hamlet_films['year'] // 10) * 10

# %% [markdown]
# # How many leading (n=1) roles were available to actors, and how many to actresses, in each year of the 1950s?

# %%
# Assuming you have a DataFrame named cast with columns "year", "type", and "n"

# Filter for leading roles in the 1950s
leading_roles_1950s = cast[(cast['n'] == 1) & (cast['year'] >= 1950) & (cast['year'] < 1960)]

# Group by year and type, then count roles
roles_count = leading_roles_1950s.groupby(['year', 'type']).size().unstack()

print(roles_count)
# Out:
# type  actor  actress
# year
# 1950    625      288
# 1951    651      285
# 1952    613      304
# 1953    664      312
# 1954    636      316
# 1955    648      285
# 1956    668      307
# 1957    739      315
# 1958    715      301
# 1959    733      327

# %% [markdown]
# # In the 1950s decade taken as a whole, how many total roles were available to actors, and how many to actresses, for each "n" number 1 through 5?

# %%
# Assuming you have a DataFrame named cast with columns "year", "type", and "n"

# Filter for roles in the 1950s with n-values from 1 through 5
filtered_roles = cast[(cast['year'] >= 1950) & (cast['year'] < 1960) & (cast['n'].between(1, 5))]

# Group by 'n' value and role type, then count roles
role_counts = filtered_roles.groupby(['n', 'type']).size().unstack()

print(role_counts)
# Out:
# type  actor  actress
# n
# 1.0    6692     3040
# 2.0    4640     4635
# 3.0    5654     3201
# 4.0    5663     2881
# 5.0    5674     2592

# %% [markdown]
# # Use groupby() to determine how many roles are listed for each of the Pink Panther movies.

# %%
# Assuming you have a DataFrame named cast with a column "title"

# Filter for movies containing "Pink Panther" in their title
pink_panther_movies = cast[cast['title'].str.contains('Pink Panther', case=False, na=False)]

# Group by title and count roles
roles_count = pink_panther_movies.groupby('title').size()

print(roles_count)
# Out:
# title
# Curse of the Pink Panther          67
# Revenge of the Pink Panther        68
# Son of the Pink Panther            46
# The Pink Panther                  111
# The Pink Panther 2                 84
# The Pink Panther Strikes Again     70
# The Return of the Pink Panther     30
# Trail of the Pink Panther          41
# dtype: int64

# %% [markdown]
# # List, in order by year, each of the films in which Frank Oz has played more than 1 role.

# %%
# Assuming you have a DataFrame named cast with columns "name", "year", and "title"

# Filter for roles played by Frank Oz
frank_oz_movies = cast[cast['name'] == 'Frank Oz']

# Group by title and year, count roles, and filter results
multiple_roles = frank_oz_movies.groupby(['title', 'year']).size()
multiple_roles_movies = multiple_roles[multiple_roles > 1].reset_index()

# Sorting by year and displaying the results
sorted_movies = multiple_roles_movies.sort_values(by='year')
print(sorted_movies[['title', 'year']])
# Out:
#                                   title  year
# 8                      The Muppet Movie  1979
# 0        An American Werewolf in London  1981
# 6                The Great Muppet Caper  1981
# 5                      The Dark Crystal  1982
# 9            The Muppets Take Manhattan  1984
# 1                      Follow That Bird  1985
# 7            The Muppet Christmas Carol  1992
# 2                Muppet Treasure Island  1996
# 3                    Muppets from Space  1999
# 4  The Adventures of Elmo in Grouchland  1999

# %% [markdown]
# # List each of the characters that Frank Oz has portrayed at least twice.

# %%
# Assuming you have a DataFrame named cast with columns "name" and "character"

# Filter for roles played by Frank Oz
frank_oz_roles = cast[cast['name'] == 'Frank Oz']

# Group by character, count occurrences, and filter results
recurring_characters = frank_oz_roles.groupby('character').size()
recurring_characters_filtered = recurring_characters[recurring_characters >= 2]

print(recurring_characters_filtered)
# Out:
# character
# Animal            6
# Bert              3
# Cookie Monster    5
# Fozzie Bear       4
# Grover            2
# Miss Piggy        6
# Sam the Eagle     5
# Yoda              6
# dtype: int64

# %% [markdown]
# # Define a year as a "Superman year" whose films feature more Superman characters than Batman. How many years in film history have been Superman years?

# %%
# Assuming you have a DataFrame named cast with columns "year" and "character"

# Filter for roles named "Superman" or "Batman"
superman_batman = cast[cast['character'].isin(['Superman', 'Batman'])]

# Group by year and character and count occurrences
character_counts = superman_batman.groupby(['year', 'character']).size().unstack().fillna(0)

# Find the years where Superman occurrences are more than Batman occurrences
superman_years = character_counts[character_counts['Superman'] > character_counts['Batman']]

# Count the number of Superman years
number_of_superman_years = len(superman_years)

print(f"There have been {number_of_superman_years} Superman years in film history.")
# Out:
# There have been 11 Superman years in film history.

# %% [markdown]
# # How many years have been "Batman years", with more Batman characters than Superman characters?

# %%
# Assuming you have a DataFrame named cast with columns "year" and "character"

# Filter for roles named "Superman" or "Batman"
superman_batman = cast[cast['character'].isin(['Superman', 'Batman'])]

# Group by year and character and count occurrences
character_counts = superman_batman.groupby(['year', 'character']).size().unstack().fillna(0)

# Find the years where Batman occurrences are more than Superman occurrences
batman_years = character_counts[character_counts['Batman'] > character_counts['Superman']]

# Count the number of Batman years
number_of_batman_years = len(batman_years)

print(f"There have been {number_of_batman_years} Batman years in film history.")
# Out:
# There have been 27 Batman years in film history.

# %% [markdown]
# # Plot the number of actor roles each year and the number of actress roles each year over the history of film.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named cast with columns "year" and "type"

# Group by year and type, then count roles
roles_per_year = cast.groupby(['year', 'type']).size().unstack()

# Plotting
roles_per_year.plot(figsize=(12, 7))
plt.title("Number of Actor & Actress Roles Over the History of Film")
plt.xlabel("Year")
plt.ylabel("Number of Roles")
plt.legend(title="Role Type")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the number of actor roles each year and the number of actress roles each year, but this time as a kind 'area' plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named cast with columns "year" and "type"

# Group by year and type, then count roles
roles_per_year = cast.groupby(['year', 'type']).size().unstack()

# Plotting using area plot
roles_per_year.plot(kind='area', figsize=(12, 7), alpha=0.5) # alpha controls the transparency
plt.title("Number of Actor & Actress Roles Over the History of Film")
plt.xlabel("Year")
plt.ylabel("Number of Roles")
plt.legend(title="Role Type")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the difference between the number of actor roles each year and the number of actress roles each year over the history of film.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named cast with columns "year" and "type"

# Group by year and type, then count roles
roles_per_year = cast.groupby(['year', 'type']).size().unstack()

# Calculate the difference between actor and actress roles for each year
difference = roles_per_year['actor'] - roles_per_year['actress']

# Plotting the difference
difference.plot(figsize=(12, 7))
plt.title("Difference Between Number of Actor & Actress Roles Over the History of Film")
plt.xlabel("Year")
plt.ylabel("Difference in Roles")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the fraction of roles that have been 'actor roles bach year in the history of film.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named cast with columns "year" and "type"

# Group by year and type, then count roles
roles_per_year = cast.groupby(['year', 'type']).size().unstack()

# Calculate the fraction of actor roles for each year
actor_fraction = roles_per_year['actor'] / (roles_per_year['actor'] + roles_per_year['actress'])

# Plotting the fraction
actor_fraction.plot(figsize=(12, 7))
plt.title("Fraction of 'Actor' Roles Over the History of Film")
plt.xlabel("Year")
plt.ylabel("Fraction of Actor Roles")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the fraction of supporting (n=2) roles that have been 'actor roles each year in the history of film

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named cast with columns "year", "type", and "n"

# Filter for supporting roles
supporting_roles = cast[cast['n'] == 2]

# Group by year and type, then count roles
roles_per_year = supporting_roles.groupby(['year', 'type']).size().unstack().fillna(0)

# Calculate the fraction of actor roles for each year
actor_fraction = roles_per_year['actor'] / (roles_per_year['actor'] + roles_per_year['actress'])

# Plotting the fraction
actor_fraction.plot(figsize=(12, 7))
plt.title("Fraction of 'Actor' Supporting Roles Over the History of Film")
plt.xlabel("Year")
plt.ylabel("Fraction of Actor Supporting Roles")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Build a plot with a line for each rank n=1 through n=3, where the line shows what fraction of that rank's roles were 'actor' roles for each year in the history of film.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named cast with columns "year", "type", and "n"

# Filter for roles with n values from 1 to 3
filtered_roles = cast[cast['n'].isin([1, 2, 3])]

# Group by year, type, and n, then count roles
role_counts = filtered_roles.groupby(['year', 'n', 'type']).size().unstack('type').fillna(0)

# Calculate the fraction of actor roles for each n value
fractions = role_counts['actor'] / (role_counts['actor'] + role_counts['actress'])

# Plotting the fractions for each n value
fig, ax = plt.subplots(figsize=(12, 7))
for rank in [1, 2, 3]:
    fractions.xs(rank, level='n').plot(ax=ax, label=f'n={rank}')

plt.title("Fraction of 'Actor' Roles for Ranks n=1 through n=3 Over the History of Film")
plt.xlabel("Year")
plt.ylabel("Fraction of Actor Roles")
plt.legend(title="Rank (n value)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Make a bar plot of the months in which movies with "Christmas" in their title tend to be released in the USA

# %%
import pandas as pd

# Read the CSV
release_dates = pd.read_csv('release_dates.csv')

# Print out the first few rows to inspect
print(release_dates.head())
# Out:
#                     title  year      country        date
# 0   #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                   #BKKY  2016     Cambodia  2017-10-12
# 2                 #Beings  2015      Romania  2015-01-29
# 3               #Captured  2017          USA  2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines  2015-01-21

# %%
# import matplotlib.pyplot as plt

# Filter movies with "Christmas" in their title and released in the USA
christmas_movies = release_dates[
    (release_dates['title'].str.contains('Christmas', case=False)) & 
    (release_dates['country'] == 'USA')
]

# Convert 'date' column to datetime format
christmas_movies['date'] = pd.to_datetime(christmas_movies['date'], errors='coerce')

# Extract month
christmas_movies['month'] = christmas_movies['date'].dt.month

# Count movies released in each month
month_counts = christmas_movies['month'].value_counts().sort_index()

# Plot
month_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Months Movies with "Christmas" in Title are Released in the USA')
plt.xlabel('Month')
plt.ylabel('Number of Movies')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\2217566128.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   christmas_movies['date'] = pd.to_datetime(christmas_movies['date'], errors='coerce')
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\2217566128.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   christmas_movies['month'] = christmas_movies['date'].dt.month

# %% [markdown]
# # Make a bar plot of the months in which movies whose titles start with "The Hobbit" are released in the USA.

# %%
import matplotlib.pyplot as plt

# Filter movies starting with "The Hobbit" and released in the USA
hobbit_movies = release_dates[
    (release_dates['title'].str.startswith('The Hobbit')) & 
    (release_dates['country'] == 'USA')
]

# Convert the 'date' column to datetime format
hobbit_movies['date'] = pd.to_datetime(hobbit_movies['date'], errors='coerce')

# Extract month
hobbit_movies['month'] = hobbit_movies['date'].dt.month

# Count movies released in each month
month_counts = hobbit_movies['month'].value_counts().sort_index()

# Plot
month_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Months Movies Starting with "The Hobbit" are Released in the USA')
plt.xlabel('Month')
plt.ylabel('Number of Movies')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\641949965.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hobbit_movies['date'] = pd.to_datetime(hobbit_movies['date'], errors='coerce')
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\641949965.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hobbit_movies['month'] = hobbit_movies['date'].dt.month

# %% [markdown]
# # Make a bar plot of the day of the week on which movies with "Romance" in their title tend to be released in the USA

# %%
import matplotlib.pyplot as plt

# Assuming you already have the release_dates DataFrame loaded

# Filter movies with "Romance" in their title and released in the USA
romance_movies = release_dates[
    (release_dates['title'].str.contains('Romance', case=False)) & 
    (release_dates['country'] == 'USA')
]

# Convert the 'date' column to datetime format if it's not already
romance_movies['date'] = pd.to_datetime(romance_movies['date'], errors='coerce')

# Extract day of the week
romance_movies['day_of_week'] = romance_movies['date'].dt.day_name()

# Count movies released on each day of the week
day_counts = romance_movies['day_of_week'].value_counts().reindex([
    'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'
])

# Plot
day_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Day of the Week Movies with "Romance" in Title are Released in the USA')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\154736496.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   romance_movies['date'] = pd.to_datetime(romance_movies['date'], errors='coerce')
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\154736496.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   romance_movies['day_of_week'] = romance_movies['date'].dt.day_name()

# %% [markdown]
# # Make a bar plot of the day of the week on which movies with "Action" in their title tend to be released in the USA.

# %%
# import matplotlib.pyplot as plt

# Assuming you already have the release_dates DataFrame loaded

# Filter movies with "Action" in their title and released in the USA
action_movies = release_dates[
    (release_dates['title'].str.contains('Action', case=False)) & 
    (release_dates['country'] == 'USA')
]

# Convert the 'date' column to datetime format if it's not already
action_movies['date'] = pd.to_datetime(action_movies['date'], errors='coerce')

# Extract day of the week
action_movies['day_of_week'] = action_movies['date'].dt.day_name()

# Count movies released on each day of the week
day_counts = action_movies['day_of_week'].value_counts().reindex([
    'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'
])

# Plot
day_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Day of the Week Movies with "Action" in Title are Released in the USA')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\2375825443.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   action_movies['date'] = pd.to_datetime(action_movies['date'], errors='coerce')
# C:\Users\hp\AppData\Local\Temp\ipykernel_2044\2375825443.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   action_movies['day_of_week'] = action_movies['date'].dt.day_name()

# %% [markdown]
# # On which date was each Judi Dench movie from the 1990s released in the USA?

# %%
# Assuming you have both cast and release_dates DataFrames loaded

# Filter the cast DataFrame for movies that Judi Dench acted in during the 1990s
judi_dench_90s = cast[(cast['name'] == 'Judi Dench') & (cast['year'].between(1990, 1999))]

# Join with the release_dates DataFrame to get USA release dates
release_dates_judi = judi_dench_90s.merge(release_dates[release_dates['country'] == 'USA'], on=['title', 'year'])

# Select relevant columns and drop duplicates
result = release_dates_judi[['title', 'year', 'date']].drop_duplicates()

print(result)
# Out:
#                      title  year        date
# 0                GoldenEye  1995  1995-11-17
# 1                   Hamlet  1996  1996-12-25
# 2             Jack & Sarah  1995  1996-03-22
# 3                Mrs Brown  1997  1997-10-03
# 4      Shakespeare in Love  1998  1999-01-08
# 5       Tea with Mussolini  1999  1999-05-14
# 6  The World Is Not Enough  1999  1999-11-19
# 7      Tomorrow Never Dies  1997  1997-12-19

# %% [markdown]
# # In which months do films with Judi Dench tend to be released in the USA?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have both cast and release_dates DataFrames loaded

# Filter the cast DataFrame for movies that Judi Dench acted in
judi_dench_movies = cast[cast['name'] == 'Judi Dench']

# Join with the release_dates DataFrame to get USA release dates
release_dates_judi = judi_dench_movies.merge(release_dates[release_dates['country'] == 'USA'], on=['title', 'year'])

# Convert the 'date' column to a datetime format
release_dates_judi['date'] = pd.to_datetime(release_dates_judi['date'])

# Extract month from the date
release_dates_judi['month'] = release_dates_judi['date'].dt.month

# Count the number of movies released in each month
month_counts = release_dates_judi['month'].value_counts().sort_index()

# Plot
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_counts.index = month_names[:len(month_counts)]
month_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Months in which movies with Judi Dench are released in the USA')
plt.xlabel('Month')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()

# %% [markdown]
# # In which months do films with Tom Cruise tend to be released in the USA?

# %%
# ... [the rest of your code remains unchanged]

# Get the unique months present in month_counts
unique_months = month_counts.index

# Map these unique month numbers to their names
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
mapped_names = [month_names[i-1] for i in unique_months]

# Set the index
month_counts.index = mapped_names

# Plot
month_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Months in which movies with Tom Cruise are released in the USA')
plt.xlabel('Month')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()
